# %% [markdown]
# <a href="https://colab.research.google.com/github/WilliamYkZhang/COMP551_A2/blob/master/model_selection_xgboost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Preprocessing
from sklearn.preprocessing import Normalizer
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.feature_selection import SelectKBest
from sklearn.pipeline import Pipeline
from nltk.corpus import stopwords
import pandas as pd

# Transformers 
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer, TfidfTransformer 
from sklearn.decomposition import TruncatedSVD

# Models 
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC 
import xgboost as xgb
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB

# Module to write final params 
import csv
import datetime
import pickle

# %%
# Download stopwords
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Get a list of stopwords
stopwords = stopwords.words("english")

# Transformers 
c_vect = CountVectorizer(lowercase=True, encoding="utf-8", decode_error="ignore", strip_accents='unicode',stop_words=stopwords, analyzer = "word")
tfidf_vect = TfidfVectorizer(lowercase=True, encoding = "utf-8",  decode_error = 'ignore', strip_accents='unicode', stop_words=stopwords, analyzer = "word")  
tfidf_trans = TfidfTransformer()
svd = TruncatedSVD()
nml = Normalizer()

# Estimators 
log_reg = LogisticRegression()
svc = SVC() # class weight , experiement values 
xgb_clf = xgb.XGBClassifier(objective='multi:softmax')
decision_tree_clf = DecisionTreeClassifier()
rff = RandomForestClassifier()
multi_NB = MultinomialNB()

# %%
# Building pipeline 
pipeline_cvect = Pipeline([('cvect', c_vect), ('clf', multi_NB)], verbose=True)
pipeline_cvect_svd = Pipeline([('cvect', c_vect),('svd', svd), ("nml", nml), ('clf', multi_NB)], verbose=True)
pipeline_tfidf = Pipeline([('tfidf', tfidf_vect), ('clf', xgb_clf)], verbose=True)
pipeline_tfidf_svd = Pipeline([('tfidf', tfidf_vect), ('svd', svd), ("nml", nml), ('clf', multi_NB)], verbose=True)
pipeline_cvect_tfidf = Pipeline([('cvect', c_vect),('tfidf', tfidf_trans), ('kbest', SelectKBest()), ('clf', multi_NB)], verbose=True)

# Instantiate parameters for pipeline     
parameters_cvect = {
    'cvect__max_df': (0.5, 0.75, 1.0),
    'cvect__max_features': (None, 5000, 10000, 50000),
    'cvect__ngram_range': ((1, 1), (1, 2)),  # unigrams or bigrams
    'cvect__max_df': (0.5, 0.75, 0.9), # ignore terms that have a document frequency strictly higher than the given threshold
    'cvect__min_df': (0.025, 0.05, 0.1), #  ignore terms that have a document frequency strictly lower than the given threshold
    'clf__alpha': (0.25, 0.5, 0.75),
    'clf__fit_prior': (True, False),   
    }

parameters_cvect_svd = {
    'cvect__max_df': (0.5, 0.75, 1.0),
    'cvect__max_features': (None, 5000, 10000, 50000),
    'cvect__ngram_range': ((1, 1), (1, 2)),  # unigrams or bigrams
    'cvect__max_df': (0.5, 0.75, 0.9), # ignore terms that have a document frequency strictly higher than the given threshold
    'cvect__min_df': (0.025, 0.05, 0.1), #  ignore terms that have a document frequency strictly lower than the given threshold
    'svd__n_components' : (10, 500,1000,2500, 5000, 7500, 10000),
    'svd__algorithm': ("arpack", "randomized"),
    'nml__norm' : ('l1', 'l2', 'max'),
    'clf__alpha': (0.25, 0.5, 0.75),
    'clf__fit_prior': (True, False),   
    }

parameters_tfidf = {
    'tfidf__max_features': (None, 10000, 25000, 50000),
    'tfidf__use_idf': (True, False), # Enable inverse-document-frequency reweighting.
    'tfidf__max_df': (0.5, 0.75, 0.9), # ignore terms that have a document frequency strictly higher than the given threshold
    'tfidf__min_df': (0.025, 0.05, 0.1), #  ignore terms that have a document frequency strictly lower than the given threshold
    'tfidf__norm': ('l1', 'l2', None), # regularization term
    'tfidf__smooth_idf': (True, False), # Smooth idf weights by adding one to document frequencies, as if an extra document was seen containing every term in the collection exactly once.Prevents zero divisions
    'tfidf__ngram_range': ((1, 1), (1, 2)), # n-grams to be extracted     
}  

parameters_tfidf_svd = {
    'tfidf__max_features': (None, 10000, 25000, 50000),
    'tfidf__use_idf': (True, False), # Enable inverse-document-frequency reweighting.
    'tfidf__max_df': (0.5, 0.75, 0.9), # ignore terms that have a document frequency strictly higher than the given threshold
    'tfidf__min_df': (0.025, 0.05, 0.1), #  ignore terms that have a document frequency strictly lower than the given threshold
    'tfidf__norm': ('l1', 'l2', None), # regularization term
    'tfidf__smooth_idf': (True, False), # Smooth idf weights by adding one to document frequencies, as if an extra document was seen containing every term in the collection exactly once.Prevents zero divisions
    'tfidf__ngram_range': ((1, 1), (1, 2)), # n-grams to be extracted
    'svd__n_components' : (10, 500,1000,2500, 5000, 7500, 10000),
    'svd__algorithm': ("arpack", "randomized"),
    'nml__norm' : ('l1', 'l2', 'max'),
    'clf__alpha': (0.25, 0.5, 0.75),
    'clf__fit_prior': (True, False),      
}  

parameters_cvect_tfidf = {
    'cvect__max_features': (None,1000,?| 5000, 10000),
    'cvect__ngram_range': ((1, 1), (1, 2)),  # unigrams or bigrams
    'cvect__max_df': (0.75, 0.9), # ignore terms that have a document frequency strictly higher than the given threshold
    'cvect__min_df': (0.05, 0.1), #  ignore terms that have a document frequency strictly lower than the given threshold
    'tfidf__use_idf': (True, False), # Enable inverse-document-frequency reweighting.
    'tfidf__norm': ('l1', 'l2', None), # regularization term
    'tfidf__smooth_idf': (True, False), # Smooth idf weights by adding one to document frequencies, as if an extra document was seen containing every term in the collection exactly once.Prevents zero divisions
    'tfidf__sublinear': (True, False),
    'clf__alpha': (0.25, 0.5, 0.75),
    'clf__fit_prior': (True, False),       
}

# %%
# Read DataFrame
stemmed_df = pd.read_csv("https://raw.githubusercontent.com/WilliamYkZhang/COMP551_A2/master/preprocessed_reddit_train_SnowballStemmer.csv?token=AKKZG4BDT5OWZKKHNN5INRK5WKCPQ")
lemmatized_df = pd.read_csv("https://raw.githubusercontent.com/WilliamYkZhang/COMP551_A2/master/preprocessed_reddit_train_WordNetLemmatizer.csv?token=AKKZG4A66B7WQED7PFYWW525WKCRE")

# Separate X and Y 
X_stem = stemmed_df["cleaned"]
y_stem = stemmed_df["label"]
X_lemma = lemmatized_df["cleaned"]
y_lemma = lemmatized_df["label"]

# %%
# Use GridSearch cross validation to find the best features extraction and hyperparameters
gs_CV = GridSearchCV(pipeline_tfidf, param_grid=parameters_tfidf, cv=5)
gs_CV.fit(X_lemma, y_lemma)
print("Performing grid search...")
print("Pipeline: ", [name for name, _ in pipeline_tfidf.steps])
print("Best parameter (CV score={0:.3f}):".format(gs_CV.best_score_))
print("Best parameters set: {} \nBest estimator parameters {}.".format(gs_CV.best_params_, gs_CV.best_estimator_.get_params()))
# Out:
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.1min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.7s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.1min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.1min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  37.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  38.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  37.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  37.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.7s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  37.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.1min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.1min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.7s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.1min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.7s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  37.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  37.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  37.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  37.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  37.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.1min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.1min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  41.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  41.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.7s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  41.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.7s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  41.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  41.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.1min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.7s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.1min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  41.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  41.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  41.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  41.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  41.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.7s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.7s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.7s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  32.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  32.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  32.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.6s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  38.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  38.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  38.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  38.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  38.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.2s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.2s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  38.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  39.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  38.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  38.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  38.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.6s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.6s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.6s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  41.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  42.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  42.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  42.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.7s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  42.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total= 1.2min
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  42.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  42.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  42.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  42.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  42.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  32.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  32.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  32.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  32.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  32.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  32.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.2s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  32.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  42.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  45.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.9s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.7s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  23.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  23.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.7s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  23.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.2s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.2s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  28.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.6s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  23.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  23.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  23.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.2s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  23.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.2s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  23.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.2s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  23.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.2s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  23.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  23.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  24.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  19.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  19.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  19.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  19.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.9s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  17.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  17.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.2s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.2s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.2s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.2s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.1s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.2s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.1s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.2s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.3s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.2s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.2s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.2s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  19.1s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.5s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  19.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  20.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.3s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  19.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  19.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   7.4s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  18.9s
# ...
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  31.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.2s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  42.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.6s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.5s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.4s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  26.7s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.9s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  44.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.7s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.9s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.0s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.8s
# [Pipeline] ............... (step 2 of 2) Processing clf, total=  43.8s
# [Pipeline] ............. (step 1 of 2) Processing tfidf, total=   1.7s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f32fa3da6679> in <module>()
#       1 gs_CV = GridSearchCV(pipeline_tfidf, param_grid=parameters_tfidf, cv=5)
# ----> 2 gs_CV.fit(X_lemma, y_lemma)
#       3 print("Performing grid search...")
#       4 print("Pipeline: ", [name for name, _ in pipeline_tfidf.steps])
#       5 print("Best parameter (CV score={0:.3f}):".format(gs_CV.best_score_))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     686                 return results
#     687
# --> 688             self._run_search(evaluate_candidates)
#     689
#     690         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1147     def _run_search(self, evaluate_candidates):
#    1148         """Search all candidates in param_grid"""
# -> 1149         evaluate_candidates(ParameterGrid(self.param_grid))
#    1150
#    1151
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     665                                for parameters, (train, test)
#     666                                in product(candidate_params,
# --> 667                                           cv.split(X, y, groups)))
#     668
#     669                 if len(out) < 1:
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1004                 self._iterating = self._original_iterator is not None
#    1005
# -> 1006             while self.dispatch_one_batch(iterator):
#    1007                 pass
#    1008
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     832                 return False
#     833             else:
# --> 834                 self._dispatch(tasks)
#     835                 return True
#     836
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     751         with self._lock:
#     752             job_idx = len(self._jobs)
# --> 753             job = self._backend.apply_async(batch, callback=cb)
#     754             # A job can complete so quickly than its callback is
#     755             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     199     def apply_async(self, func, callback=None):
#     200         """Schedule a func to be run"""
# --> 201         result = ImmediateResult(func)
#     202         if callback:
#     203             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     580         # Don't delay the application, to avoid keeping the input
#     581         # arguments in memory
# --> 582         self.results = batch()
#     583
#     584     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     514             estimator.fit(X_train, **fit_params)
#     515         else:
# --> 516             estimator.fit(X_train, y_train, **fit_params)
#     517
#     518     except Exception as e:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     354                                  self._log_message(len(self.steps) - 1)):
#     355             if self._final_estimator != 'passthrough':
# --> 356                 self._final_estimator.fit(Xt, y, **fit_params)
#     357         return self
#     358
#
# /usr/local/lib/python3.6/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     730                               evals_result=evals_result, obj=obj, feval=feval,
#     731                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 732                               callbacks=callbacks)
#     733
#     734         self.objective = xgb_options["objective"]
#
# /usr/local/lib/python3.6/dist-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# /usr/local/lib/python3.6/dist-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1107         if fobj is None:
#    1108             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1109                                                     dtrain.handle))
#    1110         else:
#    1111             pred = self.predict(dtrain)
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-f32fa3da6679> in <module>()
#       1 gs_CV = GridSearchCV(pipeline_tfidf, param_grid=parameters_tfidf, cv=5)
# ----> 2 gs_CV.fit(X_lemma, y_lemma)
#       3 print("Performing grid search...")
#       4 print("Pipeline: ", [name for name, _ in pipeline_tfidf.steps])
#       5 print("Best parameter (CV score={0:.3f}):".format(gs_CV.best_score_))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     686                 return results
#     687
# --> 688             self._run_search(evaluate_candidates)
#     689
#     690         # For multi-metric evaluation, store the best_index_, best_params_ and
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1147     def _run_search(self, evaluate_candidates):
#    1148         """Search all candidates in param_grid"""
# -> 1149         evaluate_candidates(ParameterGrid(self.param_grid))
#    1150
#    1151
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params)
#     665                                for parameters, (train, test)
#     666                                in product(candidate_params,
# --> 667                                           cv.split(X, y, groups)))
#     668
#     669                 if len(out) < 1:
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    1004                 self._iterating = self._original_iterator is not None
#    1005
# -> 1006             while self.dispatch_one_batch(iterator):
#    1007                 pass
#    1008
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     832                 return False
#     833             else:
# --> 834                 self._dispatch(tasks)
#     835                 return True
#     836
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in _dispatch(self, batch)
#     751         with self._lock:
#     752             job_idx = len(self._jobs)
# --> 753             job = self._backend.apply_async(batch, callback=cb)
#     754             # A job can complete so quickly than its callback is
#     755             # called before we get here, causing self._jobs to
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     199     def apply_async(self, func, callback=None):
#     200         """Schedule a func to be run"""
# --> 201         result = ImmediateResult(func)
#     202         if callback:
#     203             callback(result)
#
# /usr/local/lib/python3.6/dist-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     580         # Don't delay the application, to avoid keeping the input
#     581         # arguments in memory
# --> 582         self.results = batch()
#     583
#     584     def get(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in __call__(self)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/joblib/parallel.py in <listcomp>(.0)
#     254         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     255             return [func(*args, **kwargs)
# --> 256                     for func, args, kwargs in self.items]
#     257
#     258     def __len__(self):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     514             estimator.fit(X_train, **fit_params)
#     515         else:
# --> 516             estimator.fit(X_train, y_train, **fit_params)
#     517
#     518     except Exception as e:
#
# /usr/local/lib/python3.6/dist-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     354                                  self._log_message(len(self.steps) - 1)):
#     355             if self._final_estimator != 'passthrough':
# --> 356                 self._final_estimator.fit(Xt, y, **fit_params)
#     357         return self
#     358
#
# /usr/local/lib/python3.6/dist-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     730                               evals_result=evals_result, obj=obj, feval=feval,
#     731                               verbose_eval=verbose, xgb_model=xgb_model,
# --> 732                               callbacks=callbacks)
#     733
#     734         self.objective = xgb_options["objective"]
#
# /usr/local/lib/python3.6/dist-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# /usr/local/lib/python3.6/dist-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# /usr/local/lib/python3.6/dist-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1107         if fobj is None:
#    1108             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# -> 1109                                                     dtrain.handle))
#    1110         else:
#    1111             pred = self.predict(dtrain)
#
# KeyboardInterrupt:
